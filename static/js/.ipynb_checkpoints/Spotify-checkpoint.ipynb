# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pprint
import json
import pandas as pd

# %%
df = pd.read_csv('LatLong.txt', encoding="utf-8")
df
# Out:
#                           Country Code  Latitude  Longitude  \
# 0              Argentine Republic   AR -34.00000  -64.00000
# 1             Republic of Austria   AT  47.33333   13.33333
# 2       Commonwealth of Australia   AU -25.00000  135.00000
# 3              Kingdom of Belgium   BE  50.75000    4.50000
# 4            Republic of Bulgaria   BG  42.66667   25.25000
# ..                            ...  ...       ...        ...
# 56                         Taiwan   TW  24.00000  121.00000
# 57                  United States   US  39.76000  -98.50000
# 58   Oriental Republic of Uruguay   UY -33.00000  -56.00000
# 59  Socialist Republic of Vietnam   VN  16.16667  107.83333
# 60       Republic of South Africa   ZA -29.00000   24.00000
#
#                   Playlist
# 0   37i9dQZEVXbMMy2roB9myp
# 1   37i9dQZEVXbKNHh6NIXu36
# 2   37i9dQZEVXbJPcfkRz0wJ0
# 3   37i9dQZEVXbJNSeeHswcKB
# 4   37i9dQZEVXbNfM2w2mq1B8
# ..                     ...
# 56  37i9dQZEVXbMnZEatlMSiu
# 57  37i9dQZEVXbLRQDuF5jeBp
# 58  37i9dQZEVXbMJJi3wgRbAy
# 59  37i9dQZEVXbLdGSmz6xilI
# 60  37i9dQZEVXbMH2jvi6jvjk
#
# [61 rows x 5 columns]

# %%
CLIENT_ID = "d76e0263612746c1891673bca5220cd0"
CLIENT_SECRET = "7c34c892933d446fae874d28b3f6a9b2"

credentials = oauth2.SpotifyClientCredentials(
        client_id=CLIENT_ID,
        client_secret=CLIENT_SECRET)

token = credentials.get_access_token()
spotify = spotipy.Spotify(auth=token)

playlist_info = []
country_list = []

for i in range(0,10):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))


#playlist = spotify.playlist_tracks('37i9dQZEVXbMMy2roB9myp', market=None, additional_types=('track', ))
# res = spotify.audio_features(track)
# pprint.pprint(playlist['items'][0]['track'])
print(playlist_info)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
# [{'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMMy2roB9myp/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '1970-01-01T00:00:00Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hdhHgpxyniooUiQVaPxQ0'}, 'href': 'https://api.spotify.com/v1/artists/5hdhHgpxyniooUiQVaPxQ0', 'id': '5hdhHgpxyniooUiQVaPxQ0', 'name': 'Nio Garcia', 'type': 'artist', 'uri': 'spotify:artist:5hdhHgpxyniooUiQVaPxQ0'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'}, 'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66', 'id': '2R21vXR83lH98kGeO99Y66', 'name': 'Anuel AA', 'type': 'artist', 'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'}, 'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W', 'id': '7iK8PXO48WeuP03g8YR51W', 'name': 'Myke Towers', 'type': 'artist', 'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5emzM1P5GGeroiivNQgCq4'}, 'href': 'https://api.spotify.com/v1/albums/5emzM1P5GGeroiivNQgCq4', 'id': '5emzM1P5GGeroiivNQgCq4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2735a89169ff864c80931b2b073', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e025a89169ff864c80931b2b073', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048515a89169ff864c80931b2b073', 'width': 64}], 'name': 'La Jeepeta (Remix)', 'release_date': '2020-04-24', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:5emzM1P5GGeroiivNQgCq4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5hdhHgpxyniooUiQVaPxQ0'}, 'href': 'https://api.spotify.com/v1/artists/5hdhHgpxyniooUiQVaPxQ0', 'id': '5hdhHgpxyniooUiQVaPxQ0', 'name': 'Nio Garcia', 'type': 'artist', 'uri': 'spotify:artist:5hdhHgpxyniooUiQVaPxQ0'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'}, 'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66', 'id': '2R21vXR83lH98kGeO99Y66', 'name': 'Anuel AA', 'type': 'artist', 'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/7iK8PXO48WeuP03g8YR51W'}, 'href': 'https://api.spotify.com/v1/artists/7iK8PXO48WeuP03g8YR51W', 'id': '7iK8PXO48WeuP03g8YR51W', 'name': 'Myke Towers', 'type': 'artist', 'uri': 'spotify:artist:7iK8PXO48WeuP03g8YR51W'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1GKIlPFdcewHtpDVCQ8zmJ'}, 'href': 'https://api.spotify.com/v1/artists/1GKIlPFdcewHtpDVCQ8zmJ', 'id': '1GKIlPFdcewHtpDVCQ8zmJ', 'name': 'Brray', 'type': 'artist', 'uri': 'spotify:artist:1GKIlPFdcewHtpDVCQ8zmJ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Wb38LDP3N4tkobValgE9D'}, 'href': 'https://api.spotify.com/v1/artists/3Wb38LDP3N4tkobValgE9D', 'id': '3Wb38LDP3N4tkobValgE9D', 'name': 'Juanka', 'type': 'artist', 'uri': 'spotify:artist:3Wb38LDP3N4tkobValgE9D'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK',  ...

# %%
print(len(playlist_info))
# Out:
# 10

# %%
for i in range(10,20):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))

# %%
for i in range(20,30):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))

# %%
for i in range(30,40):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))

# %%
for i in range(40,50):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))

# %%
for i in range(50,61):
    #print(playlist)
    country_list.append(df['Playlist'][i])
    playlist_info.append(spotify.playlist_tracks(df['Playlist'][i], market=None, additional_types=('track', )))

# %%
song_id = playlist_info[1]['items'][track]['track']['id']
feat = spotify.audio_features(song_id)

# %%
print(feat[0])
# Out:
# {'danceability': 0.885, 'energy': 0.578, 'key': 5, 'loudness': -7.416, 'mode': 0, 'speechiness': 0.0783, 'acousticness': 0.0739, 'instrumentalness': 0.0903, 'liveness': 0.102, 'valence': 0.388, 'tempo': 131.999, 'type': 'audio_features', 'id': '5CqkgDH8QZjSqqI3HmYxDD', 'uri': 'spotify:track:5CqkgDH8QZjSqqI3HmYxDD', 'track_href': 'https://api.spotify.com/v1/tracks/5CqkgDH8QZjSqqI3HmYxDD', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CqkgDH8QZjSqqI3HmYxDD', 'duration_ms': 178933, 'time_signature': 4}

# %%
country_dict = {}

for playlist in range(61):
    for track in range(3):
        song_id = playlist_info[playlist]['items'][track]['track']['id']
        uri = country_list[playlist]
        feat = spotify.audio_features(song_id)
        #print(uri)
        if uri not in country_dict.keys():
            dict_list = []
            dict_list.append(feat[0])
            country_dict[uri] = dict_list
        else:
            dict_list.append(feat[0])
            country_dict[uri] = dict_list
            
pprint.pprint(country_dict)
        
#         song_id.append(playlist_info[playlist]['items'][track]['track']['id'])
# pprint.pprint(song_id)
# Out:
# {'37i9dQZEVXbIP3c3fqVrJY': [{'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334},
#                             {'acousticness': 0.0167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#                              'danceability': 0.77,
#                              'duration_ms': 176840,
#                              'energy': 0.724,
#                              'id': '24Yi9hE78yPEbZ4kxyoXAI',
#                              'instrumentalness': 0.0107,
#                              'key': 8,
#                              'liveness': 0.353,
#                              'loudness': -5.484,
#                              'mode': 1,
#                              'speechiness': 0.0495,
#                              'tempo': 121.975,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#                              'valence': 0.898},
#                             {'acousticness': 0.164,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0t0loWmgC8Z32RXj6RFvZA',
#                              'danceability': 0.855,
#                              'duration_ms': 180923,
#                              'energy': 0.704,
#                              'id': '0t0loWmgC8Z32RXj6RFvZA',
#                              'instrumentalness': 0,
#                              'key': 7,
#                              'liveness': 0.0998,
#                              'loudness': -6.58,
#                              'mode': 1,
#                              'speechiness': 0.24,
#                              'tempo': 130.025,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0t0loWmgC8Z32RXj6RFvZA',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0t0loWmgC8Z32RXj6RFvZA',
#                              'valence': 0.567}],
#  '37i9dQZEVXbIPWwFssbupI': [{'acousticness': 0.172,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KBwGCY9RYD9t2zjeW4h48',
#                              'danceability': 0.945,
#                              'duration_ms': 141893,
#                              'energy': 0.676,
#                              'id': '0KBwGCY9RYD9t2zjeW4h48',
#                              'instrumentalness': 0.00036,
#                              'key': 1,
#                              'liveness': 0.322,
#                              'loudness': -6.6,
#                              'mode': 1,
#                              'speechiness': 0.207,
#                              'tempo': 123.109,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0KBwGCY9RYD9t2zjeW4h48',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0KBwGCY9RYD9t2zjeW4h48',
#                              'valence': 0.631},
#                             {'acousticness': 0.702,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ab3CQvDlAVttThZucwGQ1',
#                              'danceability': 0.65,
#                              'duration_ms': 236000,
#                              'energy': 0.469,
#                              'id': '6ab3CQvDlAVttThZucwGQ1',
#                              'instrumentalness': 0.249,
#                              'key': 2,
#                              'liveness': 0.106,
#                              'loudness': -8.676,
#                              'mode': 0,
#                              'speechiness': 0.184,
#                              'tempo': 191.853,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/6ab3CQvDlAVttThZucwGQ1',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:6ab3CQvDlAVttThZucwGQ1',
#                              'valence': 0.378},
#                             {'acousticness': 0.213,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7b0ZEfaKg3OctqL115hUAg',
#                              'danceability': 0.844,
#                              'duration_ms': 163273,
#                              'energy': 0.781,
#                              'id': '7b0ZEfaKg3OctqL115hUAg',
#                              'instrumentalness': 0,
#                              'key': 0,
#                              'liveness': 0.303,
#                              'loudness': -4.718,
#                              'mode': 1,
#                              'speechiness': 0.0985,
#                              'tempo': 121.994,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7b0ZEfaKg3OctqL115hUAg',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7b0ZEfaKg3OctqL115hUAg',
#                              'valence': 0.695}],
#  '37i9dQZEVXbIQnj7RRhdSX': [{'acousticness': 0.048,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MLu1cFYL4ikdRTdasCQT9',
#                              'danceability': 0.703,
#                              'duration_ms': 180000,
#                              'energy': 0.704,
#                              'id': '0MLu1cFYL4ikdRTdasCQT9',
#                              'instrumentalness': 0,
#                              'key': 6,
#                              'liveness': 0.41,
#                              'loudness': -6.117,
#                              'mode': 0,
#                              'speechiness': 0.0641,
#                              'tempo': 139.933,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0MLu1cFYL4ikdRTdasCQT9',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0MLu1cFYL4ikdRTdasCQT9',
#                              'valence': 0.725},
#                             {'acousticness': 0.113,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/47xPl1gvgdx4Z9dNUuloPg',
#                              'danceability': 0.711,
#                              'duration_ms': 177810,
#                              'energy': 0.916,
#                              'id': '47xPl1gvgdx4Z9dNUuloPg',
#                              'instrumentalness': 0,
#                              'key': 11,
#                              'liveness': 0.188,
#                              'loudness': -4.678,
#                              'mode': 1,
#                              'speechiness': 0.0587,
#                              'tempo': 130.013,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/47xPl1gvgdx4Z9dNUuloPg',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:47xPl1gvgdx4Z9dNUuloPg',
#                              'valence': 0.79},
#                             {'acousticness': 0.167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EXLYWZGnmYC01H53WUAhi',
#                              'danceability': 0.75,
#                              'duration_ms': 170579,
#                              'energy': 0.581,
#                              'id': '5EXLYWZGnmYC01H53WUAhi',
#                              'instrumentalness': 0,
#                              'key': 5,
#                              'liveness': 0.203,
#                              'loudness': -9.957,
#                              'mode': 1,
#                              'speechiness': 0.128,
#                              'tempo': 121.081,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/5EXLYWZGnmYC01H53WUAhi',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:5EXLYWZGnmYC01H53WUAhi',
#                              'valence': 0.624}],
#  '37i9dQZEVXbISk8kxnzfCq': [{'acousticness': 0.0103,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DEZmgHKAvm41k4J3R2E9Y',
#                              'danceability': 0.607,
#                              'duration_ms': 295177,
#                              'energy': 0.829,
#                              'id': '2DEZmgHKAvm41k4J3R2E9Y',
#                              'instrumentalness': 0,
#                              'key': 2,
#                              'liveness': 0.107,
#                              'loudness': -4.074,
#                              'mode': 1,
#                              'speechiness': 0.379,
#                              'tempo': 96.172,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/2DEZmgHKAvm41k4J3R2E9Y',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:2DEZmgHKAvm41k4J3R2E9Y',
#                              'valence': 0.685},
#                             {'acousticness': 0.021,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SqqAgdovOE24BzxIClpjw',
#                              'danceability': 0.86,
#                              'duration_ms': 172127,
#                              'energy': 0.758,
#                              'id': '0SqqAgdovOE24BzxIClpjw',
#                              'instrumentalness': 6.54e-05,
#                              'key': 11,
#                              'liveness': 0.344,
#                              'loudness': -5.16,
#                              'mode': 1,
#                              'speechiness': 0.0695,
#                              'tempo': 97.014,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0SqqAgdovOE24BzxIClpjw',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0SqqAgdovOE24BzxIClpjw',
#                              'valence': 0.453},
#                             {'acousticness': 0.193,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/380HmhwTE2NJgawn1NwkXi',
#                              'danceability': 0.663,
#                              'duration_ms': 150720,
#                              'energy': 0.598,
#                              'id': '380HmhwTE2NJgawn1NwkXi',
#                              'instrumentalness': 8.02e-05,
#                              'key': 11,
#                              'liveness': 0.0856,
#                              'loudness': -4.042,
#                              'mode': 1,
#                              'speechiness': 0.17,
#                              'tempo': 172.245,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/380HmhwTE2NJgawn1NwkXi',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:380HmhwTE2NJgawn1NwkXi',
#                              'valence': 0.4}],
#  '37i9dQZEVXbIVYVBNw9D5K': [{'acousticness': 0.314,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JsCNbqn3zbL7mrsSlY3L2',
#                              'danceability': 0.701,
#                              'duration_ms': 225036,
#                              'energy': 0.575,
#                              'id': '7JsCNbqn3zbL7mrsSlY3L2',
#                              'instrumentalness': 1.22e-05,
#                              'key': 8,
#                              'liveness': 0.13,
#                              'loudness': -9.062,
#                              'mode': 0,
#                              'speechiness': 0.206,
#                              'tempo': 139.9,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7JsCNbqn3zbL7mrsSlY3L2',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7JsCNbqn3zbL7mrsSlY3L2',
#                              'valence': 0.471},
#                             {'acousticness': 0.0253,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BjmOMyfT4PBKbZuSCwWPc',
#                              'danceability': 0.932,
#                              'duration_ms': 167350,
#                              'energy': 0.448,
#                              'id': '7BjmOMyfT4PBKbZuSCwWPc',
#                              'instrumentalness': 0,
#                              'key': 8,
#                              'liveness': 0.104,
#                              'loudness': -4.491,
#                              'mode': 0,
#                              'speechiness': 0.136,
#                              'tempo': 103.98,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7BjmOMyfT4PBKbZuSCwWPc',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7BjmOMyfT4PBKbZuSCwWPc',
#                              'valence': 0.736},
#                             {'acousticness': 0.239,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1iGBNeM1l8uGQMjJX3gzdZ',
#                              'danceability': 0.785,
#                              'duration_ms': 170628,
#                              'energy': 0.726,
#                              'id': '1iGBNeM1l8uGQMjJX3gzdZ',
#                              'instrumentalness': 0,
#                              'key': 10,
#                              'liveness': 0.0742,
#                              'loudness': -6.979,
#                              'mode': 0,
#                              'speechiness': 0.0623,
#                              'tempo': 100.026,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/1iGBNeM1l8uGQMjJX3gzdZ',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:1iGBNeM1l8uGQMjJX3gzdZ',
#                              'valence': 0.262}],
#  '37i9dQZEVXbJ6IpvItkve3': [{'acousticness': 0.134,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02WuyBR56QN3B6ZC0BeC3f',
#                              'danceability': 0.757,
#                              'duration_ms': 173400,
#                              'energy': 0.826,
#                              'id': '02WuyBR56QN3B6ZC0BeC3f',
#                              'instrumentalness': 0.204,
#                              'key': 8,
#                              'liveness': 0.508,
#                              'loudness': -5.691,
#                              'mode': 1,
#                              'speechiness': 0.0739,
#                              'tempo': 100.023,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/02WuyBR56QN3B6ZC0BeC3f',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:02WuyBR56QN3B6ZC0BeC3f',
#                              'valence': 0.384},
#                             {'acousticness': 0.0562,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bwwEAtEfHVgO56U0yEvG8',
#                              'danceability': 0.813,
#                              'duration_ms': 178913,
#                              'energy': 0.542,
#                              'id': '3bwwEAtEfHVgO56U0yEvG8',
#                              'instrumentalness': 0.000149,
#                              'key': 8,
#                              'liveness': 0.0691,
#                              'loudness': -5.68,
#                              'mode': 0,
#                              'speechiness': 0.0589,
#                              'tempo': 138.035,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3bwwEAtEfHVgO56U0yEvG8',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3bwwEAtEfHVgO56U0yEvG8',
#                              'valence': 0.893},
#                             {'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334}],
#  '37i9dQZEVXbJNSeeHswcKB': [{'acousticness': 0.247,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ytR5pFWmSjzHJIeQkgog4',
#                              'danceability': 0.746,
#                              'duration_ms': 181733,
#                              'energy': 0.69,
#                              'id': '7ytR5pFWmSjzHJIeQkgog4',
#                              'instrumentalness': 0,
#                              'key': 11,
#                              'liveness': 0.101,
#                              'loudness': -7.956,
#                              'mode': 1,
#                              'speechiness': 0.164,
#                              'tempo': 89.977,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7ytR5pFWmSjzHJIeQkgog4',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7ytR5pFWmSjzHJIeQkgog4',
#                              'valence': 0.497},
#                             {'acousticness': 0.172,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KBwGCY9RYD9t2zjeW4h48',
#                              'danceability': 0.945,
#                              'duration_ms': 141893,
#                              'energy': 0.676,
#                              'id': '0KBwGCY9RYD9t2zjeW4h48',
#                              'instrumentalness': 0.00036,
#                              'key': 1,
#                              'liveness': 0.322,
#                              'loudness': -6.6,
#                              'mode': 1,
#                              'speechiness': 0.207,
#                              'tempo': 123.109,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0KBwGCY9RYD9t2zjeW4h48',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0KBwGCY9RYD9t2zjeW4h48',
#                              'valence': 0.631},
#                             {'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334}],
#  '37i9dQZEVXbJPcfkRz0wJ0': [{'acousticness': 0.247,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ytR5pFWmSjzHJIeQkgog4',
#                              'danceability': 0.746,
#                              'duration_ms': 181733,
#                              'energy': 0.69,
#                              'id': '7ytR5pFWmSjzHJIeQkgog4',
#                              'instrumentalness': 0,
#                              'key': 11,
#                              'liveness': 0.101,
#                              'loudness': -7.956,
#                              'mode': 1,
#                              'speechiness': 0.164,
#                              'tempo': 89.977,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7ytR5pFWmSjzHJIeQkgog4',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7ytR5pFWmSjzHJIeQkgog4',
#                              'valence': 0.497},
#                             {'acousticness': 0.0167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#                              'danceability': 0.77,
#                              'duration_ms': 176840,
#                              'energy': 0.724,
#                              'id': '24Yi9hE78yPEbZ4kxyoXAI',
#                              'instrumentalness': 0.0107,
#                              'key': 8,
#                              'liveness': 0.353,
#                              'loudness': -5.484,
#                              'mode': 1,
#                              'speechiness': 0.0495,
#                              'tempo': 121.975,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#                              'valence': 0.898},
#                             {'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334}],
#  '37i9dQZEVXbJWuzDrTxbKS': [{'acousticness': 0.0117,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qWaZ2KzYhyrv1ILuAcIIv',
#                              'danceability': 0.957,
#                              'duration_ms': 177609,
#                              'energy': 0.743,
#                              'id': '6qWaZ2KzYhyrv1ILuAcIIv',
#                              'instrumentalness': 0.257,
#                              'key': 2,
#                              'liveness': 0.0994,
#                              'loudness': -3.931,
#                              'mode': 1,
#                              'speechiness': 0.0611,
#                              'tempo': 105.022,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/6qWaZ2KzYhyrv1ILuAcIIv',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:6qWaZ2KzYhyrv1ILuAcIIv',
#                              'valence': 0.673},
#                             {'acousticness': 0.0167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#                              'danceability': 0.77,
#                              'duration_ms': 176840,
#                              'energy': 0.724,
#                              'id': '24Yi9hE78yPEbZ4kxyoXAI',
#                              'instrumentalness': 0.0107,
#                              'key': 8,
#                              'liveness': 0.353,
#                              'loudness': -5.484,
#                              'mode': 1,
#                              'speechiness': 0.0495,
#                              'tempo': 121.975,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#                              'valence': 0.898},
#                             {'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334}],
#  '37i9dQZEVXbJfdy5b0KP7W': [{'acousticness': 0.125,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'danceability': 0.805,
#                              'duration_ms': 184255,
#                              'energy': 0.562,
#                              'id': '3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'instrumentalness': 4.96e-06,
#                              'key': 7,
#                              'liveness': 0.148,
#                              'loudness': -3.117,
#                              'mode': 0,
#                              'speechiness': 0.105,
#                              'tempo': 172.094,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'valence': 0.767},
#                             {'acousticness': 0.237,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jT8Nl0shPS8115is0wD2Q',
#                              'danceability': 0.606,
#                              'duration_ms': 209766,
#                              'energy': 0.853,
#                              'id': '0jT8Nl0shPS8115is0wD2Q',
#                              'instrumentalness': 0,
#                              'key': 9,
#                              'liveness': 0.251,
#                              'loudness': -2.975,
#                              'mode': 1,
#                              'speechiness': 0.0545,
#                              'tempo': 178.043,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0jT8Nl0shPS8115is0wD2Q',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0jT8Nl0shPS8115is0wD2Q',
#                              'valence': 0.822},
#                             {'acousticness': 0.237,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50ZC4PM7hywH27RcCfViau',
#                              'danceability': 0.824,
#                              'duration_ms': 197721,
#                              'energy': 0.631,
#                              'id': '50ZC4PM7hywH27RcCfViau',
#                              'instrumentalness': 0.000116,
#                              'key': 0,
#                              'liveness': 0.0531,
#                              'loudness': -2.791,
#                              'mode': 1,
#                              'speechiness': 0.0809,
#                              'tempo': 171.965,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/50ZC4PM7hywH27RcCfViau',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:50ZC4PM7hywH27RcCfViau',
#                              'valence': 0.678}],
#  '37i9dQZEVXbJiZcmkrIHGU': [{'acousticness': 0.386,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yZCjDTxzZxx1kll1sRjGc',
#                              'danceability': 0.788,
#                              'duration_ms': 146028,
#                              'energy': 0.491,
#                              'id': '3yZCjDTxzZxx1kll1sRjGc',
#                              'instrumentalness': 0.00088,
#                              'key': 8,
#                              'liveness': 0.107,
#                              'loudness': -9.884,
#                              'mode': 1,
#                              'speechiness': 0.109,
#                              'tempo': 98.543,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3yZCjDTxzZxx1kll1sRjGc',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3yZCjDTxzZxx1kll1sRjGc',
#                              'valence': 0.271},
#                             {'acousticness': 0.0739,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5CqkgDH8QZjSqqI3HmYxDD',
#                              'danceability': 0.885,
#                              'duration_ms': 178933,
#                              'energy': 0.578,
#                              'id': '5CqkgDH8QZjSqqI3HmYxDD',
#                              'instrumentalness': 0.0903,
#                              'key': 5,
#                              'liveness': 0.102,
#                              'loudness': -7.416,
#                              'mode': 0,
#                              'speechiness': 0.0783,
#                              'tempo': 131.999,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/5CqkgDH8QZjSqqI3HmYxDD',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:5CqkgDH8QZjSqqI3HmYxDD',
#                              'valence': 0.388},
#                             {'acousticness': 0.247,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ytR5pFWmSjzHJIeQkgog4',
#                              'danceability': 0.746,
#                              'duration_ms': 181733,
#                              'energy': 0.69,
#                              'id': '7ytR5pFWmSjzHJIeQkgog4',
#                              'instrumentalness': 0,
#                              'key': 11,
#                              'liveness': 0.101,
#                              'loudness': -7.956,
#                              'mode': 1,
#                              'speechiness': 0.164,
#                              'tempo': 89.977,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7ytR5pFWmSjzHJIeQkgog4',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7ytR5pFWmSjzHJIeQkgog4',
#                              'valence': 0.497}],
#  '37i9dQZEVXbJiyhoAPEfMK': [{'acousticness': 0.247,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ytR5pFWmSjzHJIeQkgog4',
#                              'danceability': 0.746,
#                              'duration_ms': 181733,
#                              'energy': 0.69,
#                              'id': '7ytR5pFWmSjzHJIeQkgog4',
#                              'instrumentalness': 0,
#                              'key': 11,
#                              'liveness': 0.101,
#                              'loudness': -7.956,
#                              'mode': 1,
#                              'speechiness': 0.164,
#                              'tempo': 89.977,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7ytR5pFWmSjzHJIeQkgog4',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7ytR5pFWmSjzHJIeQkgog4',
#                              'valence': 0.497},
#                             {'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334},
#                             {'acousticness': 0.0167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#                              'danceability': 0.77,
#                              'duration_ms': 176840,
#                              'energy': 0.724,
#                              'id': '24Yi9hE78yPEbZ4kxyoXAI',
#                              'instrumentalness': 0.0107,
#                              'key': 8,
#                              'liveness': 0.353,
#                              'loudness': -5.484,
#                              'mode': 1,
#                              'speechiness': 0.0495,
#                              'tempo': 121.975,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#                              'valence': 0.898}],
#  '37i9dQZEVXbJlM6nvL1nD1': [{'acousticness': 0.125,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'danceability': 0.805,
#                              'duration_ms': 184255,
#                              'energy': 0.562,
#                              'id': '3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'instrumentalness': 4.96e-06,
#                              'key': 7,
#                              'liveness': 0.148,
#                              'loudness': -3.117,
#                              'mode': 0,
#                              'speechiness': 0.105,
#                              'tempo': 172.094,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'valence': 0.767},
#                             {'acousticness': 0.021,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SqqAgdovOE24BzxIClpjw',
#                              'danceability': 0.86,
#                              'duration_ms': 172127,
#                              'energy': 0.758,
#                              'id': '0SqqAgdovOE24BzxIClpjw',
#                              'instrumentalness': 6.54e-05,
#                              'key': 11,
#                              'liveness': 0.344,
#                              'loudness': -5.16,
#                              'mode': 1,
#                              'speechiness': 0.0695,
#                              'tempo': 97.014,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0SqqAgdovOE24BzxIClpjw',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0SqqAgdovOE24BzxIClpjw',
#                              'valence': 0.453},
#                             {'acousticness': 0.193,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/380HmhwTE2NJgawn1NwkXi',
#                              'danceability': 0.663,
#                              'duration_ms': 150720,
#                              'energy': 0.598,
#                              'id': '380HmhwTE2NJgawn1NwkXi',
#                              'instrumentalness': 8.02e-05,
#                              'key': 11,
#                              'liveness': 0.0856,
#                              'loudness': -4.042,
#                              'mode': 1,
#                              'speechiness': 0.17,
#                              'tempo': 172.245,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/380HmhwTE2NJgawn1NwkXi',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:380HmhwTE2NJgawn1NwkXi',
#                              'valence': 0.4}],
#  '37i9dQZEVXbJlfUljuZExa': [{'acousticness': 0.223,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HBZA5flZLE435QTztThqH',
#                              'danceability': 0.597,
#                              'duration_ms': 228482,
#                              'energy': 0.45,
#                              'id': '4HBZA5flZLE435QTztThqH',
#                              'instrumentalness': 0,
#                              'key': 8,
#                              'liveness': 0.382,
#                              'loudness': -6.658,
#                              'mode': 1,
#                              'speechiness': 0.0418,
#                              'tempo': 178.765,
#                              'time_signature': 3,
#                              'track_href': 'https://api.spotify.com/v1/tracks/4HBZA5flZLE435QTztThqH',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:4HBZA5flZLE435QTztThqH',
#                              'valence': 0.537},
#                             {'acousticness': 0.731,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eJMfftS33KTjuF7lTsMCx',
#                              'danceability': 0.726,
#                              'duration_ms': 173333,
#                              'energy': 0.431,
#                              'id': '7eJMfftS33KTjuF7lTsMCx',
#                              'instrumentalness': 0,
#                              'key': 8,
#                              'liveness': 0.696,
#                              'loudness': -8.765,
#                              'mode': 0,
#                              'speechiness': 0.135,
#                              'tempo': 144.026,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7eJMfftS33KTjuF7lTsMCx',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7eJMfftS33KTjuF7lTsMCx',
#                              'valence': 0.348},
#                             {'acousticness': 0.612,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DpNNXFMMxQEKl7r0ykkWA',
#                              'danceability': 0.68,
#                              'duration_ms': 179867,
#                              'energy': 0.729,
#                              'id': '4DpNNXFMMxQEKl7r0ykkWA',
#                              'instrumentalness': 0,
#                              'key': 5,
#                              'liveness': 0.224,
#                              'loudness': -5.077,
#                              'mode': 1,
#                              'speechiness': 0.0475,
#                              'tempo': 123.97,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/4DpNNXFMMxQEKl7r0ykkWA',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:4DpNNXFMMxQEKl7r0ykkWA',
#                              'valence': 0.446}],
#  '37i9dQZEVXbJp9wcIM9Eo5': [{'acousticness': 0.125,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'danceability': 0.805,
#                              'duration_ms': 184255,
#                              'energy': 0.562,
#                              'id': '3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'instrumentalness': 4.96e-06,
#                              'key': 7,
#                              'liveness': 0.148,
#                              'loudness': -3.117,
#                              'mode': 0,
#                              'speechiness': 0.105,
#                              'tempo': 172.094,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'valence': 0.767},
#                             {'acousticness': 0.0103,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DEZmgHKAvm41k4J3R2E9Y',
#                              'danceability': 0.607,
#                              'duration_ms': 295177,
#                              'energy': 0.829,
#                              'id': '2DEZmgHKAvm41k4J3R2E9Y',
#                              'instrumentalness': 0,
#                              'key': 2,
#                              'liveness': 0.107,
#                              'loudness': -4.074,
#                              'mode': 1,
#                              'speechiness': 0.379,
#                              'tempo': 96.172,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/2DEZmgHKAvm41k4J3R2E9Y',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:2DEZmgHKAvm41k4J3R2E9Y',
#                              'valence': 0.685},
#                             {'acousticness': 0.021,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SqqAgdovOE24BzxIClpjw',
#                              'danceability': 0.86,
#                              'duration_ms': 172127,
#                              'energy': 0.758,
#                              'id': '0SqqAgdovOE24BzxIClpjw',
#                              'instrumentalness': 6.54e-05,
#                              'key': 11,
#                              'liveness': 0.344,
#                              'loudness': -5.16,
#                              'mode': 1,
#                              'speechiness': 0.0695,
#                              'tempo': 97.014,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0SqqAgdovOE24BzxIClpjw',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0SqqAgdovOE24BzxIClpjw',
#                              'valence': 0.453}],
#  '37i9dQZEVXbJqfMFK4d691': [{'acousticness': 0.335,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0aCTSZQTlmnjQucALTF00s',
#                              'danceability': 0.802,
#                              'duration_ms': 212406,
#                              'energy': 0.579,
#                              'id': '0aCTSZQTlmnjQucALTF00s',
#                              'instrumentalness': 0.000311,
#                              'key': 11,
#                              'liveness': 0.173,
#                              'loudness': -4.78,
#                              'mode': 0,
#                              'speechiness': 0.0869,
#                              'tempo': 99.992,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0aCTSZQTlmnjQucALTF00s',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0aCTSZQTlmnjQucALTF00s',
#                              'valence': 0.234},
#                             {'acousticness': 0.125,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZG8N7aWw2meb6UrI5ZmnZ',
#                              'danceability': 0.805,
# ...
#                              'tempo': 172.245,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/380HmhwTE2NJgawn1NwkXi',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:380HmhwTE2NJgawn1NwkXi',
#                              'valence': 0.4}],
#  '37i9dQZEVXbNZbJ6TZelCq': [{'acousticness': 0.066,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GiTUiS0A8ORsZesaOSwj2',
#                              'danceability': 0.918,
#                              'duration_ms': 178004,
#                              'energy': 0.521,
#                              'id': '6GiTUiS0A8ORsZesaOSwj2',
#                              'instrumentalness': 6.3e-05,
#                              'key': 1,
#                              'liveness': 0.692,
#                              'loudness': -7.824,
#                              'mode': 1,
#                              'speechiness': 0.114,
#                              'tempo': 108.236,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/6GiTUiS0A8ORsZesaOSwj2',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:6GiTUiS0A8ORsZesaOSwj2',
#                              'valence': 0.309},
#                             {'acousticness': 0.0167,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24Yi9hE78yPEbZ4kxyoXAI',
#                              'danceability': 0.77,
#                              'duration_ms': 176840,
#                              'energy': 0.724,
#                              'id': '24Yi9hE78yPEbZ4kxyoXAI',
#                              'instrumentalness': 0.0107,
#                              'key': 8,
#                              'liveness': 0.353,
#                              'loudness': -5.484,
#                              'mode': 1,
#                              'speechiness': 0.0495,
#                              'tempo': 121.975,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/24Yi9hE78yPEbZ4kxyoXAI',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:24Yi9hE78yPEbZ4kxyoXAI',
#                              'valence': 0.898},
#                             {'acousticness': 0.0319,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dVvWnj4D8JGkKvo6Hucso',
#                              'danceability': 0.744,
#                              'duration_ms': 202667,
#                              'energy': 0.422,
#                              'id': '3dVvWnj4D8JGkKvo6Hucso',
#                              'instrumentalness': 0.00011,
#                              'key': 1,
#                              'liveness': 0.11,
#                              'loudness': -8.946,
#                              'mode': 1,
#                              'speechiness': 0.294,
#                              'tempo': 180.006,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3dVvWnj4D8JGkKvo6Hucso',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3dVvWnj4D8JGkKvo6Hucso',
#                              'valence': 0.493}],
#  '37i9dQZEVXbNfM2w2mq1B8': [{'acousticness': 0.0264,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NhDYoQTYCdWHTvlbGVgwo',
#                              'danceability': 0.611,
#                              'duration_ms': 132303,
#                              'energy': 0.688,
#                              'id': '4NhDYoQTYCdWHTvlbGVgwo',
#                              'instrumentalness': 0,
#                              'key': 1,
#                              'liveness': 0.251,
#                              'loudness': -5.688,
#                              'mode': 1,
#                              'speechiness': 0.341,
#                              'tempo': 178.462,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/4NhDYoQTYCdWHTvlbGVgwo',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:4NhDYoQTYCdWHTvlbGVgwo',
#                              'valence': 0.393},
#                             {'acousticness': 0.0319,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dVvWnj4D8JGkKvo6Hucso',
#                              'danceability': 0.744,
#                              'duration_ms': 202667,
#                              'energy': 0.422,
#                              'id': '3dVvWnj4D8JGkKvo6Hucso',
#                              'instrumentalness': 0.00011,
#                              'key': 1,
#                              'liveness': 0.11,
#                              'loudness': -8.946,
#                              'mode': 1,
#                              'speechiness': 0.294,
#                              'tempo': 180.006,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/3dVvWnj4D8JGkKvo6Hucso',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:3dVvWnj4D8JGkKvo6Hucso',
#                              'valence': 0.493},
#                             {'acousticness': 0.233,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39Yp9wwQiSRIDOvrVg7mbk',
#                              'danceability': 0.716,
#                              'duration_ms': 165978,
#                              'energy': 0.537,
#                              'id': '39Yp9wwQiSRIDOvrVg7mbk',
#                              'instrumentalness': 0,
#                              'key': 0,
#                              'liveness': 0.157,
#                              'loudness': -7.648,
#                              'mode': 0,
#                              'speechiness': 0.0514,
#                              'tempo': 129.979,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/39Yp9wwQiSRIDOvrVg7mbk',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:39Yp9wwQiSRIDOvrVg7mbk',
#                              'valence': 0.28}],
#  '37i9dQZEVXbO3qyFxbkOE1': [{'acousticness': 0.00146,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VjIjW4GlUZAMYd2vXMi3b',
#                              'danceability': 0.514,
#                              'duration_ms': 200040,
#                              'energy': 0.73,
#                              'id': '0VjIjW4GlUZAMYd2vXMi3b',
#                              'instrumentalness': 9.54e-05,
#                              'key': 1,
#                              'liveness': 0.0897,
#                              'loudness': -5.934,
#                              'mode': 1,
#                              'speechiness': 0.0598,
#                              'tempo': 171.005,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b',
#                              'valence': 0.334},
#                             {'acousticness': 0.0103,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DEZmgHKAvm41k4J3R2E9Y',
#                              'danceability': 0.607,
#                              'duration_ms': 295177,
#                              'energy': 0.829,
#                              'id': '2DEZmgHKAvm41k4J3R2E9Y',
#                              'instrumentalness': 0,
#                              'key': 2,
#                              'liveness': 0.107,
#                              'loudness': -4.074,
#                              'mode': 1,
#                              'speechiness': 0.379,
#                              'tempo': 96.172,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/2DEZmgHKAvm41k4J3R2E9Y',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:2DEZmgHKAvm41k4J3R2E9Y',
#                              'valence': 0.685},
#                             {'acousticness': 0.0816,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lCkncy6bIB0LTMT7kvrD1',
#                              'danceability': 0.843,
#                              'duration_ms': 205933,
#                              'energy': 0.836,
#                              'id': '2lCkncy6bIB0LTMT7kvrD1',
#                              'instrumentalness': 0.00138,
#                              'key': 11,
#                              'liveness': 0.0532,
#                              'loudness': -2.474,
#                              'mode': 0,
#                              'speechiness': 0.0695,
#                              'tempo': 94.018,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/2lCkncy6bIB0LTMT7kvrD1',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:2lCkncy6bIB0LTMT7kvrD1',
#                              'valence': 0.65}],
#  '37i9dQZEVXbOa2lmxNORXQ': [{'acousticness': 0.193,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/380HmhwTE2NJgawn1NwkXi',
#                              'danceability': 0.663,
#                              'duration_ms': 150720,
#                              'energy': 0.598,
#                              'id': '380HmhwTE2NJgawn1NwkXi',
#                              'instrumentalness': 8.02e-05,
#                              'key': 11,
#                              'liveness': 0.0856,
#                              'loudness': -4.042,
#                              'mode': 1,
#                              'speechiness': 0.17,
#                              'tempo': 172.245,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/380HmhwTE2NJgawn1NwkXi',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:380HmhwTE2NJgawn1NwkXi',
#                              'valence': 0.4},
#                             {'acousticness': 0.0903,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TOmcZvw0gHa7GiXRbcYAW',
#                              'danceability': 0.795,
#                              'duration_ms': 232653,
#                              'energy': 0.542,
#                              'id': '4TOmcZvw0gHa7GiXRbcYAW',
#                              'instrumentalness': 0,
#                              'key': 6,
#                              'liveness': 0.117,
#                              'loudness': -8.106,
#                              'mode': 0,
#                              'speechiness': 0.193,
#                              'tempo': 167.823,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/4TOmcZvw0gHa7GiXRbcYAW',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:4TOmcZvw0gHa7GiXRbcYAW',
#                              'valence': 0.55},
#                             {'acousticness': 0.237,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50ZC4PM7hywH27RcCfViau',
#                              'danceability': 0.824,
#                              'duration_ms': 197721,
#                              'energy': 0.631,
#                              'id': '50ZC4PM7hywH27RcCfViau',
#                              'instrumentalness': 0.000116,
#                              'key': 0,
#                              'liveness': 0.0531,
#                              'loudness': -2.791,
#                              'mode': 1,
#                              'speechiness': 0.0809,
#                              'tempo': 171.965,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/50ZC4PM7hywH27RcCfViau',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:50ZC4PM7hywH27RcCfViau',
#                              'valence': 0.678}],
#  '37i9dQZEVXbObFQZ3JLcXt': [{'acousticness': 0.0857,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ksK7gpPDFdY4JLHr1hKfY',
#                              'danceability': 0.58,
#                              'duration_ms': 188900,
#                              'energy': 0.898,
#                              'id': '7ksK7gpPDFdY4JLHr1hKfY',
#                              'instrumentalness': 0.000254,
#                              'key': 3,
#                              'liveness': 0.478,
#                              'loudness': -1.928,
#                              'mode': 0,
#                              'speechiness': 0.0349,
#                              'tempo': 150.018,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/7ksK7gpPDFdY4JLHr1hKfY',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:7ksK7gpPDFdY4JLHr1hKfY',
#                              'valence': 0.213},
#                             {'acousticness': 0.612,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DpNNXFMMxQEKl7r0ykkWA',
#                              'danceability': 0.68,
#                              'duration_ms': 179867,
#                              'energy': 0.729,
#                              'id': '4DpNNXFMMxQEKl7r0ykkWA',
#                              'instrumentalness': 0,
#                              'key': 5,
#                              'liveness': 0.224,
#                              'loudness': -5.077,
#                              'mode': 1,
#                              'speechiness': 0.0475,
#                              'tempo': 123.97,
#                              'time_signature': 4,
#                              'track_href': 'https://api.spotify.com/v1/tracks/4DpNNXFMMxQEKl7r0ykkWA',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:4DpNNXFMMxQEKl7r0ykkWA',
#                              'valence': 0.446},
#                             {'acousticness': 0.8,
#                              'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ecC8p17cDNlxHXkuYqeR6',
#                              'danceability': 0.39,
#                              'duration_ms': 183103,
#                              'energy': 0.448,
#                              'id': '0ecC8p17cDNlxHXkuYqeR6',
#                              'instrumentalness': 0.182,
#                              'key': 5,
#                              'liveness': 0.107,
#                              'loudness': -8.57,
#                              'mode': 0,
#                              'speechiness': 0.0276,
#                              'tempo': 144.89,
#                              'time_signature': 5,
#                              'track_href': 'https://api.spotify.com/v1/tracks/0ecC8p17cDNlxHXkuYqeR6',
#                              'type': 'audio_features',
#                              'uri': 'spotify:track:0ecC8p17cDNlxHXkuYqeR6',
#                              'valence': 0.077}]}

# %%
with open('data.json', 'w+') as fp:
    json.dump(country_dict, fp, indent=4)

# %%
pprint.pprint(country_dict)

# %%
rec = spotify.artist_related_artists(artist)

# %%
recartist = []
for artist in range(10):
    recartist.append(rec['artists'][artist]['name'])
pprint.pprint(recartist)

# %%
top_song_analysis = spotify.audio_analysis(song_id[0])

# %%
(top_song_analysis['segments'][0]['loudness_max'])

# %%
for loudness in top_song_analysis['segments']:
    print (loudness['loudness_max'])

# %%
loud_dict = {}
loud_list = []

for key in country_dict:
    #pprint.pprint(country_dict[key][0]['id'])
    song_id = country_dict[key][0]['id']
    top_song_analysis = spotify.audio_analysis(song_id)
    for loudness in top_song_analysis['segments']:
        loud_list.append(loudness['loudness_max'])
    loud_dict[key] = loud_list

#pprint.pprint(loud_dict)
